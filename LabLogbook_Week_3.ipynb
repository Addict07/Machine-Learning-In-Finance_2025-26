# %%
import pandas as pd
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('telecom_churn.csv')
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
Clr = data['Churn'].map({False: 'blue', True: 'orange'})

sid = 2436362

# 2 - Total day calls
# 3 - Total night calls

plt.figure(figsize=(10, 6))
plt.scatter(data['Total day calls'], data['Total night calls'], c=Clr)
plt.xlabel('Total day calls')
plt.ylabel('Total night calls')
plt.title('Interaction between Total Day Calls and Total Night Calls by Churn Status')
plt.show()
