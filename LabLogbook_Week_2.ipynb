# %%
import pandas as pd
# This cell imports the pandas library for data manipulation.

# %%
df = pd.read_csv('/content/adult_data_mini.csv')
# This cell loads the adult data from a CSV file into a pandas DataFrame.

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Answer
# 0        2174.0           NaN              40   United-States   <=50K
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        ' Answer'],
#       dtype='object')

# %%
ID = 2436363
n = 3

# %%
Group_by_relationship = df.groupby(['relationship', 'hours-per-week'])
Group_by_relationship.size()
# This cell groups the DataFrame by 'relationship' and 'hours-per-week' and then counts the size of each group.
# Out:
# relationship   hours-per-week
# Husband        13                1
#                40                4
#                45                1
#                80                1
# Not-in-family  16                1
#                40                2
#                50                2
# Own-child      30                1
# Wife           40                2
# dtype: int64

# %%
def reduce_hours_by_one():
  """Reduces the 'hours-per-week' column by the value of 'n'."""
  df['hours-per-week'] = df['hours-per-week'] - n
  return df

reduce_hours_by_one().head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Answer
# 0        2174.0           NaN              37   United-States   <=50K
# ...

# %%
Group_by_relationship_reduce_hours = df.groupby(['relationship', 'hours-per-week'])
Group_by_relationship_reduce_hours.size()
# This cell groups the DataFrame by 'relationship' and 'hours-per-week' after reducing the hours and then counts the size of each group.
# Out:
# relationship   hours-per-week
# Husband        10                1
#                37                4
#                42                1
#                77                1
# Not-in-family  13                1
#                37                2
#                47                2
# Own-child      27                1
# Wife           37                2
# dtype: int64
